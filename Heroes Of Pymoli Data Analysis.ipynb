# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
#Van

# File to Load (Remember to Change These)
file_to_load = "/Users/vanjoisscott/Desktop/BootCamp/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
#total number of players
purchase_data.columns
# Out:
# Index(['Purchase ID', 'SN', 'Age', 'Gender', 'Item ID', 'Item Name', 'Price'], dtype='object')

# %%
totalplayers = purchase_data['SN'].nunique()
total_players_final = pd.DataFrame({"Total Players": [totalplayers]}, columns= ["Total Players"])
total_players_final
# Out:
#    Total Players
# 0            576

# %%
uniqueitems = purchase_data['Item Name'].nunique()
averageprice = purchase_data['Price'].mean()
totalrevenue = purchase_data['Price'].sum()
numpurchases = purchase_data['Purchase ID'].count()

Purchase_Table = pd.DataFrame([{"Number of Unique Items": uniqueitems,'Average Purchase Price': averageprice, 'Total Purchases': numpurchases, 'Total Revenue': totalrevenue}])

Purchase_Tabledf = np.round(Purchase_Table, decimals = 2)
Purchase_Tabledf
# Out:
#    Average Purchase Price  Number of Unique Items  Total Purchases  \
# 0                    3.05                     179              780
#
#    Total Revenue
# 0        2379.77

# %%
# Grouping the DataFrame by "Assignee"
gender_group = correctcount['Gender'].value_counts()
total_group = correctcount['Gender'].count()

correctcount = purchase_data.drop_duplicates(['SN'])


Male = correctcount["Gender"].value_counts()['Male']
Female = correctcount["Gender"].value_counts()['Female']
Other = total_group - Male - Female

MalePercent = (Male / total_group) * 100
FemalePercent = (Female / total_group) * 100
OtherPercent = (Other / total_group) * 100

# Create new DataFrame
Gender_df = pd.DataFrame({"": ['Male', 'Female', 'Other/Non-Disclosed'],
                            "Percentage of Players": [MalePercent, FemalePercent, OtherPercent],
                            "Total Count": [Male, Female, Other]})
Gender_R = np.round(Gender_df, decimals = 2)

Gender_R["Percentage of Players"] = Gender_R["Percentage of Players"].map("{:.2f}%".format)
Gender_R= Gender_R.set_index('')
Gender_R
# Out:
#                     Percentage of Players  Total Count
#
# Male                               84.03%          484
# Female                             14.06%           81
# Other/Non-Disclosed                 1.91%           11

# %%
# delete duplicates/group by gender
Gengroup = purchase_data.groupby(["Gender"])


totlpurchases = Gengroup["Purchase ID"].count()
purchPrice = Gengroup["Price"].mean()
purchValue = Gengroup["Price"].sum()


# Find data
Avg = (Gengroup["Price"].sum() / Gengroup["Purchase ID"].count())

# Create new DataFrame
pd.options.display.float_format = '${:,.2f}'.format
Purchase_df= pd.DataFrame({"Purchase Count": totlpurchases,
                              "Average Purchase Price": purchPrice,
                              "Total Purchase Value": purchValue,
                              "Avg Total Purchase per Person": Avg})

Purchase_df
# Out:
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                            113                   $3.20
# Male                              652                   $3.02
# Other / Non-Disclosed              15                   $3.35
#
#                        Total Purchase Value  Avg Total Purchase per Person
# Gender
# Female                              $361.94                          $3.20
# Male                              $1,967.64                          $3.02
# Other / Non-Disclosed                $50.19                          $3.35

# %%
# Create the bins in which Data will be held
bins = [0,9.9,14.9,19.9,24.9,29.9,34.9, 199.9, 400]
agegroup = ['< 10', '10 - 14', '15 - 19', '20 - 24', '25 - 29', '30 - 34', '35 - 39', '+40']


# Count total players by age category
total_count_age = purchase_data["SN"].nunique()

purchase_data["Age Ranges"] = pd.cut(purchase_data["Age"], bins, labels=agegroup)

# Calculate the Numbers and Percentages by Age Group
age_totals = purchase_data["Age Ranges"].value_counts()
age_percents = age_totals /totalplayers* 100
age_df = pd.DataFrame({"Total Count": age_totals, "Percentage of Players": age_percents})

age_dfF = np.round(age_df, decimals = 2)

age_dfF["Percentage of Players"] = age_dfF["Percentage of Players"].map("{:.2f}%".format)
age_dfF
# Out:
#          Total Count Percentage of Players
# 20 - 24          365                63.37%
# 15 - 19          136                23.61%
# 25 - 29          101                17.53%
# 30 - 34           73                12.67%
# 35 - 39           54                 9.38%
# 10 - 14           28                 4.86%
# < 10              23                 3.99%
# +40                0                 0.00%

# %%
age_grouped = purchase_data.groupby("Age Ranges")

# Count purchases by age group
purchase_count_age = age_grouped["Purchase ID"].count()

avg_purchase_price_age = age_grouped["Price"].mean()

# Calculate total purchase value by age group 
total_purchase_value = age_grouped["Price"].sum()

avg_purchase = total_purchase_value/totalplayers

# Create data frame with obtained values
age_demographics = pd.DataFrame({"Purchase Count": purchase_count_age,
                                 "Average Purchase Price": avg_purchase_price_age,
                                 "Total Purchase Value":total_purchase_value,
                                 "Average Purchase Total per Person": avg_purchase})

age_demographics
# Out:
#             Purchase Count  Average Purchase Price  Total Purchase Value  \
# Age Ranges
# < 10                    23                   $3.35                $77.13
# 10 - 14                 28                   $2.96                $82.78
# 15 - 19                136                   $3.04               $412.89
# 20 - 24                365                   $3.05             $1,114.06
# 25 - 29                101                   $2.90               $293.00
# 30 - 34                 73                   $2.93               $214.00
# 35 - 39                 54                   $3.44               $185.91
# +40                      0                    $nan                 $0.00
#
#             Average Purchase Total per Person
# Age Ranges
# < 10                                    $0.13
# 10 - 14                                 $0.14
# 15 - 19                                 $0.72
# 20 - 24                                 $1.93
# 25 - 29                                 $0.51
# ...

# %%
#Top Spenders
Stats = purchase_data.groupby("SN")

# Count the total purchases by name
purchase_count_spender = Stats["Purchase ID"].count()

# Calculate purchase total 
purchase_total_spender = Stats["Price"].sum()

avg_purchase_per = Stats["Price"].mean()

# Create data frame 
top_spenders = pd.DataFrame({"Purchase Count": purchase_count_spender,
                             "Average Purchase Price": avg_purchase_per,
                             "Total Purchase Value":purchase_total_spender})

top_spenders = top_spenders.sort_values("Total Purchase Value", ascending=False)

top_spenders.head()
# Out:
#              Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Lisosia93                 5                   $3.79                $18.96
# Idastidru52               4                   $3.86                $15.45
# Chamjask73                3                   $4.61                $13.83
# Iral74                    4                   $3.40                $13.62
# Iskadarya95               3                   $4.37                $13.10

# %%
goods = purchase_data[["Item ID", "Item Name", "Price"]]

# Group the item data by item id and item name 
items = goods.groupby(["Item ID","Item Name"])

# Count Items
purchase_count = items["Price"].count()

# Calculate Purchase
purchase_value = (item_stats["Price"].sum()) 

# Find individual item price
item_price = purchase_value/purchase_count

# Create data frame with obtained values
most_popular_items = pd.DataFrame({"Purchase Count": purchase_count, 
                                   "Item Price": item_price,
                                   "Total Purchase Value":purchase_value})


most_popular_items = most_popular_items.sort_values("Purchase Count", ascending=False)

most_popular_items.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 82      Nirvana                                                    9
# 19      Pursuit, Cudgel of Necromancy                              8
#
#                                                       Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm       $4.23
# 145     Fiery Glass Crusader                               $4.58
# 108     Extraction, Quickblade Of Trembling Hands          $3.53
# 82      Nirvana                                            $4.90
# 19      Pursuit, Cudgel of Necromancy                      $1.02
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...

# %%
most_popular_items = most_popular_items.sort_values("Total Purchase Value", ascending=False)

most_popular_items.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 92      Final Critic                                               8
# 103     Singed Scalpel                                             8
#
#                                                       Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm       $4.23
# 82      Nirvana                                            $4.90
# 145     Fiery Glass Crusader                               $4.58
# 92      Final Critic                                       $4.88
# 103     Singed Scalpel                                     $4.35
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...
